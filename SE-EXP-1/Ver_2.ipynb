# %% [markdown]
# <a href="https://colab.research.google.com/github/VINAY338/experiment1/blob/main/SE-EXP-1/Ver_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""SE Ver 2.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/12nejGzsH0sTbiTmh5d7Dt-aNUY_PoSc1
"""

a=float(input('Enter the value of a: '))
b=float(input('Enter the value of b: '))
c=float(input('Enter the value of c: '))
x=float(input('Enter the value of x: '))
y=a*x*x+b*x+c
print('The value of y is ',y)
# Out:
# Enter the value of a: 7
# Enter the value of b: 8
# Enter the value of c: 5
# Enter the value of x: 12
# The value of y is  1109.0
