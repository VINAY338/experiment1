# %% [markdown]
# <a href="https://colab.research.google.com/github/VINAY338/experiment1/blob/main/SE-EXP-1/Ver_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""SE Ver 1.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1yCo3XfwIVnavV58x44wwS78ySjKC57rR
"""

a=1
b=2
c=3
x=4.7
y=a*x*x+b*x+c
print('The value of y is ',y)
# Out:
# The value of y is  32.25
